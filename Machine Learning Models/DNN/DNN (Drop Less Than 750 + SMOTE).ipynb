# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from imblearn.over_sampling import SMOTE
import optuna
import matplotlib.pyplot as plt

# %%
# Load the dataset
df = pd.read_csv(r'C:\Users\khiew\Downloads\FYP Reduced Dataset.csv')

# %%
# Drop diseases with less than 1000 instances
disease_counts = df['diseases'].value_counts()
valid_diseases = disease_counts[disease_counts >= 750].index
df = df[df['diseases'].isin(valid_diseases)]

# Assuming that the target variable is 'diseases' and all other variables are input features
X = df.drop('diseases', axis=1)
y = df['diseases']

# Encode the target variable (diseases) if it's a categorical variable
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42)
num_classes = len(np.unique(y_train))
input_dim = X_train.shape[1]
print("Number of remaining classes in training set:", len(np.unique(y_train)))
print("Number of rows left:", len(df))
# Out:
# Number of remaining classes in training set: 37
# Number of rows left: 44748

# %%
# Apply SMOTE for class balancing in the training set
smote = SMOTE(random_state=42)
X_train_resampled, y_train_resampled = smote.fit_resample(X_train, y_train)

# Print the new class distribution after SMOTE
print("Class distribution after SMOTE:")
print(pd.Series(y_train_resampled).value_counts())
print("Number of remaining classes in training set:", len(np.unique(y_train_resampled)))
# Print the number of rows in the resampled training set
print("Number of rows in the resampled training set:", len(X_train_resampled))
# Out:
# Class distribution after SMOTE:
# 22    1005
# 27    1005
# 28    1005
# 34    1005
# 6     1005
# 24    1005
# 35    1005
# 12    1005
# 0     1005
# 19    1005
# 18    1005
# 30    1005
# 13    1005
# 5     1005
# 32    1005
# 23    1005
# 16    1005
# 10    1005
# 21    1005
# 33    1005
# 1     1005
# 29    1005
# 4     1005
# 20    1005
# 7     1005
# 31    1005
# 2     1005
# 36    1005
# 8     1005
# 15    1005
# 26    1005
# 9     1005
# 3     1005
# 17    1005
# 25    1005
# 11    1005
# 14    1005
# Name: count, dtype: int64
# Number of remaining classes in training set: 37
# Number of rows in the resampled training set: 37185

# %%
# Optuna objective function
def objective(trial):
    model = keras.Sequential()
    model.add(layers.Input(shape=(input_dim,)))

    # Suggest hyperparameters
    n_layers = trial.suggest_int('n_layers', 1, 3)
    for i in range(n_layers):
        num_units = trial.suggest_int(f'n_units_{i}', 64, 256, step=64)
        activation = trial.suggest_categorical(f'activation_{i}', ['relu', 'tanh'])
        model.add(layers.Dense(num_units, activation=activation))
        dropout_rate = trial.suggest_float(f'dropout_rate_{i}', 0.2, 0.5)
        model.add(layers.Dropout(dropout_rate))

    model.add(layers.Dense(num_classes, activation='softmax'))

    learning_rate = trial.suggest_float('learning_rate', 1e-4, 1e-2, log=True)
    optimizer = keras.optimizers.Adam(learning_rate=learning_rate)

    model.compile(optimizer=optimizer,
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])

    history = model.fit(X_train_resampled, y_train_resampled,
                        validation_split=0.2,
                        epochs=10,
                        batch_size=trial.suggest_categorical('batch_size', [32, 64, 128]),
                        verbose=0)

    val_accuracy = max(history.history['val_accuracy'])
    return val_accuracy

# %%
# Create Optuna study for optimization with persistent storage
study = optuna.create_study(
    direction='maximize',  # Assuming you are maximizing accuracy
    study_name="DNN_diseases_symptoms_dropextremelymore750withSMOTE_restart_study", 
    storage=r"sqlite:///C:/Users/khiew/Downloads/dnn.db", 
    load_if_exists=True  # Load the study if it already exists, to resume from the last trial
)

# Optimize the study with your objective function, you can adjust the n_trials as needed
study.optimize(objective, n_trials=20)
# Print the best trial and hyperparameters
print("\nBest Trial:")
print(study.best_trial)
print("Best Hyperparameters:")
print(study.best_trial.params)
# Out:
# [I 2025-04-25 02:14:39,205] A new study created in RDB with name: DNN_diseases_symptoms_dropextremelymore750withSMOTE_restart_study
# [I 2025-04-25 02:14:50,579] Trial 0 finished with value: 0.6915422677993774 and parameters: {'n_layers': 1, 'n_units_0': 256, 'activation_0': 'relu', 'dropout_rate_0': 0.27814029892586856, 'learning_rate': 0.00048720084146421897, 'batch_size': 32}. Best is trial 0 with value: 0.6915422677993774.
# [I 2025-04-25 02:15:06,075] Trial 1 finished with value: 0.6899287104606628 and parameters: {'n_layers': 3, 'n_units_0': 128, 'activation_0': 'tanh', 'dropout_rate_0': 0.30947825816995955, 'n_units_1': 256, 'activation_1': 'tanh', 'dropout_rate_1': 0.3473271860237313, 'n_units_2': 256, 'activation_2': 'relu', 'dropout_rate_2': 0.41437566909410767, 'learning_rate': 0.0006056012718486793, 'batch_size': 32}. Best is trial 0 with value: 0.6915422677993774.
# [I 2025-04-25 02:15:15,105] Trial 2 finished with value: 0.6895253658294678 and parameters: {'n_layers': 3, 'n_units_0': 256, 'activation_0': 'tanh', 'dropout_rate_0': 0.3353073060283255, 'n_units_1': 256, 'activation_1': 'relu', 'dropout_rate_1': 0.4606171507044649, 'n_units_2': 64, 'activation_2': 'tanh', 'dropout_rate_2': 0.3854266604584701, 'learning_rate': 0.00010537855498710726, 'batch_size': 64}. Best is trial 0 with value: 0.6915422677993774.
# [I 2025-04-25 02:15:19,674] Trial 3 finished with value: 0.6908699870109558 and parameters: {'n_layers': 2, 'n_units_0': 128, 'activation_0': 'relu', 'dropout_rate_0': 0.35162581808293425, 'n_units_1': 128, 'activation_1': 'tanh', 'dropout_rate_1': 0.36755176345577445, 'learning_rate': 0.000810873557738644, 'batch_size': 128}. Best is trial 0 with value: 0.6915422677993774.
# [I 2025-04-25 02:15:25,408] Trial 4 finished with value: 0.6915422677993774 and parameters: {'n_layers': 3, 'n_units_0': 192, 'activation_0': 'tanh', 'dropout_rate_0': 0.37447164227762064, 'n_units_1': 192, 'activation_1': 'tanh', 'dropout_rate_1': 0.3540643792960935, 'n_units_2': 128, 'activation_2': 'tanh', 'dropout_rate_2': 0.29378957361251273, 'learning_rate': 0.00039234328950144524, 'batch_size': 128}. Best is trial 0 with value: 0.6915422677993774.
# [I 2025-04-25 02:15:33,247] Trial 5 finished with value: 0.691811203956604 and parameters: {'n_layers': 3, 'n_units_0': 128, 'activation_0': 'relu', 'dropout_rate_0': 0.372241397063537, 'n_units_1': 192, 'activation_1': 'relu', 'dropout_rate_1': 0.2129600525717593, 'n_units_2': 128, 'activation_2': 'relu', 'dropout_rate_2': 0.4859006777557185, 'learning_rate': 0.004031268999232713, 'batch_size': 64}. Best is trial 5 with value: 0.691811203956604.
# [I 2025-04-25 02:15:37,785] Trial 6 finished with value: 0.6889874935150146 and parameters: {'n_layers': 2, 'n_units_0': 128, 'activation_0': 'tanh', 'dropout_rate_0': 0.4860797163770652, 'n_units_1': 128, 'activation_1': 'tanh', 'dropout_rate_1': 0.3181142864008318, 'learning_rate': 0.004413150938798816, 'batch_size': 128}. Best is trial 5 with value: 0.691811203956604.
# [I 2025-04-25 02:15:43,917] Trial 7 finished with value: 0.695441722869873 and parameters: {'n_layers': 1, 'n_units_0': 192, 'activation_0': 'tanh', 'dropout_rate_0': 0.4448076924162568, 'learning_rate': 0.00017293266011503185, 'batch_size': 64}. Best is trial 7 with value: 0.695441722869873.
# [I 2025-04-25 02:15:48,376] Trial 8 finished with value: 0.6906010508537292 and parameters: {'n_layers': 1, 'n_units_0': 256, 'activation_0': 'tanh', 'dropout_rate_0': 0.4090818387353319, 'learning_rate': 0.002965602960517152, 'batch_size': 128}. Best is trial 7 with value: 0.695441722869873.
# [I 2025-04-25 02:15:51,902] Trial 9 finished with value: 0.6947693824768066 and parameters: {'n_layers': 1, 'n_units_0': 64, 'activation_0': 'relu', 'dropout_rate_0': 0.29859673157052014, 'learning_rate': 0.003475002765630479, 'batch_size': 128}. Best is trial 7 with value: 0.695441722869873.
# [I 2025-04-25 02:15:58,596] Trial 10 finished with value: 0.6914077997207642 and parameters: {'n_layers': 1, 'n_units_0': 192, 'activation_0': 'tanh', 'dropout_rate_0': 0.4928900927020502, 'learning_rate': 0.0001406319014901245, 'batch_size': 64}. Best is trial 7 with value: 0.695441722869873.
# [I 2025-04-25 02:16:04,468] Trial 11 finished with value: 0.6864327192306519 and parameters: {'n_layers': 1, 'n_units_0': 64, 'activation_0': 'relu', 'dropout_rate_0': 0.20813511420339792, 'learning_rate': 0.009788916131157526, 'batch_size': 64}. Best is trial 7 with value: 0.695441722869873.
# [I 2025-04-25 02:16:08,463] Trial 12 finished with value: 0.6879118084907532 and parameters: {'n_layers': 2, 'n_units_0': 64, 'activation_0': 'relu', 'dropout_rate_0': 0.43253116865978414, 'n_units_1': 64, 'activation_1': 'relu', 'dropout_rate_1': 0.4894613168040819, 'learning_rate': 0.0017092653784144696, 'batch_size': 128}. Best is trial 7 with value: 0.695441722869873.
# [I 2025-04-25 02:16:15,191] Trial 13 finished with value: 0.6910044550895691 and parameters: {'n_layers': 1, 'n_units_0': 192, 'activation_0': 'relu', 'dropout_rate_0': 0.2557930616934203, 'learning_rate': 0.00022715843490597748, 'batch_size': 64}. Best is trial 7 with value: 0.695441722869873.
# [I 2025-04-25 02:16:26,455] Trial 14 finished with value: 0.6939626336097717 and parameters: {'n_layers': 1, 'n_units_0': 64, 'activation_0': 'tanh', 'dropout_rate_0': 0.44226377894230806, 'learning_rate': 0.0015249251380963999, 'batch_size': 32}. Best is trial 7 with value: 0.695441722869873.
# [I 2025-04-25 02:16:31,306] Trial 15 finished with value: 0.6876428723335266 and parameters: {'n_layers': 2, 'n_units_0': 192, 'activation_0': 'relu', 'dropout_rate_0': 0.2915875029508226, 'n_units_1': 64, 'activation_1': 'relu', 'dropout_rate_1': 0.2307963178002723, 'learning_rate': 0.00877241270825866, 'batch_size': 128}. Best is trial 7 with value: 0.695441722869873.
# [I 2025-04-25 02:16:37,840] Trial 16 finished with value: 0.692752480506897 and parameters: {'n_layers': 1, 'n_units_0': 64, 'activation_0': 'relu', 'dropout_rate_0': 0.2203565452430684, 'learning_rate': 0.0002189138604248363, 'batch_size': 64}. Best is trial 7 with value: 0.695441722869873.
# [I 2025-04-25 02:16:45,199] Trial 17 finished with value: 0.690466582775116 and parameters: {'n_layers': 2, 'n_units_0': 128, 'activation_0': 'tanh', 'dropout_rate_0': 0.3989699618306413, 'n_units_1': 64, 'activation_1': 'relu', 'dropout_rate_1': 0.43632800112689457, 'learning_rate': 0.0017658141628313906, 'batch_size': 64}. Best is trial 7 with value: 0.695441722869873.
# [I 2025-04-25 02:16:49,872] Trial 18 finished with value: 0.693155825138092 and parameters: {'n_layers': 1, 'n_units_0': 192, 'activation_0': 'relu', 'dropout_rate_0': 0.45614814321075536, 'learning_rate': 0.0011577644727548627, 'batch_size': 128}. Best is trial 7 with value: 0.695441722869873.
# [I 2025-04-25 02:17:04,238] Trial 19 finished with value: 0.6936936974525452 and parameters: {'n_layers': 1, 'n_units_0': 256, 'activation_0': 'tanh', 'dropout_rate_0': 0.3285496244748805, 'learning_rate': 0.00027591240820136736, 'batch_size': 32}. Best is trial 7 with value: 0.695441722869873.
# Best Trial:
# FrozenTrial(number=7, state=TrialState.COMPLETE, values=[0.695441722869873], datetime_start=datetime.datetime(2025, 4, 25, 2, 15, 37, 789599), datetime_complete=datetime.datetime(2025, 4, 25, 2, 15, 43, 901608), params={'n_layers': 1, 'n_units_0': 192, 'activation_0': 'tanh', 'dropout_rate_0': 0.4448076924162568, 'learning_rate': 0.00017293266011503185, 'batch_size': 64}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'n_layers': IntDistribution(high=3, log=False, low=1, step=1), 'n_units_0': IntDistribution(high=256, log=False, low=64, step=64), 'activation_0': CategoricalDistribution(choices=('relu', 'tanh')), 'dropout_rate_0': FloatDistribution(high=0.5, log=False, low=0.2, step=None), 'learning_rate': FloatDistribution(high=0.01, log=True, low=0.0001, step=None), 'batch_size': CategoricalDistribution(choices=(32, 64, 128))}, trial_id=169, value=None)
# Best Hyperparameters:
# {'n_layers': 1, 'n_units_0': 192, 'activation_0': 'tanh', 'dropout_rate_0': 0.4448076924162568, 'learning_rate': 0.00017293266011503185, 'batch_size': 64}

# %%
# Load Optuna study
study = optuna.load_study(
    study_name="DNN_diseases_symptoms_dropextremelymore750withSMOTE_restart_study",
    storage="sqlite:///C:/Users/khiew/Downloads/dnn.db"
)

# Get best parameters
best_params = study.best_trial.params

# Rebuild model using best parameters
best_model = keras.Sequential()
best_model.add(layers.Input(shape=(input_dim,)))

for i in range(best_params['n_layers']):
    best_model.add(layers.Dense(best_params[f'n_units_{i}'], activation=best_params[f'activation_{i}']))
    best_model.add(layers.Dropout(best_params[f'dropout_rate_{i}']))

best_model.add(layers.Dense(num_classes, activation='softmax'))

best_model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=best_params['learning_rate']),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# Fit the model and save training history
history = best_model.fit(
    X_train_resampled,
    y_train_resampled,
    epochs=20,
    batch_size=best_params['batch_size'],
    validation_split=0.2,
    verbose=1
)

# ===========================
# Plotting Training Lifecycle
# ===========================

plt.figure(figsize=(12, 5))

# Plot Accuracy
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy', marker='o')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy', marker='s')
plt.title('Model Accuracy over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

# Plot Loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss', marker='o')
plt.plot(history.history['val_loss'], label='Validation Loss', marker='s')
plt.title('Model Loss over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()
# Out:
# Epoch 1/20
# 465/465 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.2015 - loss: 3.3123 - val_accuracy: 0.6055 - val_loss: 2.4243
# Epoch 2/20
# 465/465 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5833 - loss: 2.2059 - val_accuracy: 0.6788 - val_loss: 1.6392
# Epoch 3/20
# 465/465 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6457 - loss: 1.5606 - val_accuracy: 0.6886 - val_loss: 1.2770
# Epoch 4/20
# 465/465 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6614 - loss: 1.2659 - val_accuracy: 0.6886 - val_loss: 1.1014
# Epoch 5/20
# 465/465 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6653 - loss: 1.1319 - val_accuracy: 0.6934 - val_loss: 1.0073
# Epoch 6/20
# 465/465 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6752 - loss: 1.0259 - val_accuracy: 0.6919 - val_loss: 0.9512
# Epoch 7/20
# 465/465 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6758 - loss: 0.9883 - val_accuracy: 0.6932 - val_loss: 0.9157
# Epoch 8/20
# 465/465 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6758 - loss: 0.9553 - val_accuracy: 0.6913 - val_loss: 0.8909
# Epoch 9/20
# 465/465 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6762 - loss: 0.9373 - val_accuracy: 0.6898 - val_loss: 0.8747
# Epoch 10/20
# 465/465 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6735 - loss: 0.9229 - val_accuracy: 0.6923 - val_loss: 0.8613
# Epoch 11/20
# 465/465 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6798 - loss: 0.9064 - val_accuracy: 0.6891 - val_loss: 0.8517
# Epoch 12/20
# 465/465 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6733 - loss: 0.9115 - val_accuracy: 0.6933 - val_loss: 0.8446
# Epoch 13/20
# 465/465 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6723 - loss: 0.8988 - val_accuracy: 0.6914 - val_loss: 0.8388
# Epoch 14/20
# 465/465 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6785 - loss: 0.8932 - val_accuracy: 0.6880 - val_loss: 0.8351
# Epoch 15/20
# 465/465 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6803 - loss: 0.8758 - val_accuracy: 0.6901 - val_loss: 0.8303
# Epoch 16/20
# 465/465 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6778 - loss: 0.8792 - val_accuracy: 0.6911 - val_loss: 0.8270
# Epoch 17/20
# 465/465 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6819 - loss: 0.8641 - val_accuracy: 0.6903 - val_loss: 0.8245
# Epoch 18/20
# 465/465 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6777 - loss: 0.8701 - val_accuracy: 0.6899 - val_loss: 0.8224
# Epoch 19/20
# 465/465 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6844 - loss: 0.8598 - val_accuracy: 0.6895 - val_loss: 0.8204
# Epoch 20/20
# 465/465 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6839 - loss: 0.8540 - val_accuracy: 0.6895 - val_loss: 0.8187

# %%
from sklearn.metrics import classification_report

y_pred_test = np.argmax(best_model.predict(X_test), axis=1)
print("Classification Report on Test Set:")
print(classification_report(y_test, y_pred_test, target_names=label_encoder.classes_))
# Out:
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 0s 672us/step
# Classification Report on Test Set:
#                                     precision    recall  f1-score   support
#
#                acute bronchiolitis       0.69      0.84      0.76       247
#                   acute bronchitis       0.78      0.65      0.71       249
#                 acute pancreatitis       1.00      0.70      0.83       257
#                            anxiety       0.95      0.86      0.90       237
#               arthritis of the hip       0.77      0.75      0.76       236
# benign prostatic hyperplasia (bph)       0.00      0.00      0.00       238
#                           bursitis       0.44      0.78      0.56       244
#                      cholecystitis       0.70      0.70      0.70       233
#     complex regional pain syndrome       1.00      0.18      0.31       258
#                         concussion       0.88      0.79      0.83       217
#      conjunctivitis due to allergy       0.73      0.88      0.80       210
#                           cystitis       0.73      0.71      0.72       252
#                      dental caries       0.93      0.89      0.91       262
#                     diverticulitis       0.94      0.62      0.75       240
#                             eczema       0.83      0.85      0.84       218
#                        esophagitis       1.00      0.88      0.93       250
#       fungal infection of the hair       1.00      0.77      0.87       227
#        gastrointestinal hemorrhage       0.67      0.87      0.75       247
#                               gout       0.28      1.00      0.44       252
#                       hypoglycemia       0.81      0.94      0.87       246
#         infectious gastroenteritis       0.44      0.73      0.55       252
#                  injury to the arm       0.74      0.47      0.58       249
#                  injury to the leg       0.74      0.53      0.62       232
#                      liver disease       0.97      0.82      0.89       233
#                    marijuana abuse       0.95      0.86      0.90       254
#      noninfectious gastroenteritis       0.42      0.09      0.15       246
#                      nose disorder       0.71      0.81      0.76       230
#      obstructive sleep apnea (osa)       0.86      0.86      0.86       235
#          peripheral nerve disorder       0.64      0.54      0.59       236
#                          pneumonia       0.93      0.64      0.76       258
#                    spinal stenosis       0.76      0.42      0.54       245
#                        spondylosis       0.51      0.65      0.57       254
#               spontaneous abortion       0.82      0.54      0.65       229
#                   sprain or strain       0.58      0.78      0.67       237
#                       strep throat       1.00      0.91      0.95       264
#                       vaginal cyst       0.52      0.87      0.66       243
#                         vulvodynia       0.70      0.60      0.65       233
#
#                           accuracy                           0.70      8950
#                          macro avg       0.74      0.70      0.69      8950
#                       weighted avg       0.74      0.70      0.69      8950
# c:\Users\khiew\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\khiew\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\khiew\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
