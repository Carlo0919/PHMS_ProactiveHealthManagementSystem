# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from imblearn.over_sampling import SMOTE
import optuna
import matplotlib.pyplot as plt

# %%
# Load the dataset
df = pd.read_csv(r'C:\Users\khiew\Downloads\FYP Reduced Dataset.csv')

# %%
# Drop diseases with less than 1000 instances
disease_counts = df['diseases'].value_counts()
valid_diseases = disease_counts[disease_counts >= 1000].index
df = df[df['diseases'].isin(valid_diseases)]

# Assuming that the target variable is 'diseases' and all other variables are input features
X = df.drop('diseases', axis=1)
y = df['diseases']

# Encode the target variable (diseases) if it's a categorical variable
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42)
num_classes = len(np.unique(y_train))
input_dim = X_train.shape[1]
print("Number of remaining classes in training set:", len(np.unique(y_train)))
print("Number of rows left:", len(df))
# Out:
# Number of remaining classes in training set: 37
# Number of rows left: 44748

# %%
# Apply SMOTE for class balancing in the training set
smote = SMOTE(random_state=42)
X_train_resampled, y_train_resampled = smote.fit_resample(X_train, y_train)

# Print the new class distribution after SMOTE
print("Class distribution after SMOTE:")
print(pd.Series(y_train_resampled).value_counts())
print("Number of remaining classes in training set:", len(np.unique(y_train_resampled)))
# Print the number of rows in the resampled training set
print("Number of rows in the resampled training set:", len(X_train_resampled))
# Out:
# Class distribution after SMOTE:
# 22    1005
# 27    1005
# 28    1005
# 34    1005
# 6     1005
# 24    1005
# 35    1005
# 12    1005
# 0     1005
# 19    1005
# 18    1005
# 30    1005
# 13    1005
# 5     1005
# 32    1005
# 23    1005
# 16    1005
# 10    1005
# 21    1005
# 33    1005
# 1     1005
# 29    1005
# 4     1005
# 20    1005
# 7     1005
# 31    1005
# 2     1005
# 36    1005
# 8     1005
# 15    1005
# 26    1005
# 9     1005
# 3     1005
# 17    1005
# 25    1005
# 11    1005
# 14    1005
# Name: count, dtype: int64
# Number of remaining classes in training set: 37
# Number of rows in the resampled training set: 37185

# %%
# Optuna objective function
def objective(trial):
    model = keras.Sequential()
    model.add(layers.Input(shape=(input_dim,)))

    # Suggest hyperparameters
    n_layers = trial.suggest_int('n_layers', 1, 3)
    for i in range(n_layers):
        num_units = trial.suggest_int(f'n_units_{i}', 64, 256, step=64)
        activation = trial.suggest_categorical(f'activation_{i}', ['relu', 'tanh'])
        model.add(layers.Dense(num_units, activation=activation))
        dropout_rate = trial.suggest_float(f'dropout_rate_{i}', 0.2, 0.5)
        model.add(layers.Dropout(dropout_rate))

    model.add(layers.Dense(num_classes, activation='softmax'))

    learning_rate = trial.suggest_float('learning_rate', 1e-4, 1e-2, log=True)
    optimizer = keras.optimizers.Adam(learning_rate=learning_rate)

    model.compile(optimizer=optimizer,
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])

    history = model.fit(X_train_resampled, y_train_resampled,
                        validation_split=0.2,
                        epochs=10,
                        batch_size=trial.suggest_categorical('batch_size', [32, 64, 128]),
                        verbose=0)

    val_accuracy = max(history.history['val_accuracy'])
    return val_accuracy

# %%
# Create Optuna study for optimization with persistent storage
study = optuna.create_study(
    direction='maximize',  # Assuming you are maximizing accuracy
    study_name="DNN_diseases_symptoms_dropextremelymore1000withSMOTE_study", 
    storage=r"sqlite:///C:/Users/khiew/Downloads/dnn.db", 
    load_if_exists=True  # Load the study if it already exists, to resume from the last trial
)

# Optimize the study with your objective function, you can adjust the n_trials as needed
study.optimize(objective, n_trials=20)
# Print the best trial and hyperparameters
print("\nBest Trial:")
print(study.best_trial)
print("Best Hyperparameters:")
print(study.best_trial.params)
# Out:
# [I 2025-04-25 01:56:16,954] A new study created in RDB with name: DNN_diseases_symptoms_dropextremelymore1000withSMOTE_study
# [I 2025-04-25 01:56:24,468] Trial 0 finished with value: 0.691811203956604 and parameters: {'n_layers': 2, 'n_units_0': 192, 'activation_0': 'relu', 'dropout_rate_0': 0.3552544325365932, 'n_units_1': 192, 'activation_1': 'tanh', 'dropout_rate_1': 0.3186699747105643, 'learning_rate': 0.0007671269007113193, 'batch_size': 64}. Best is trial 0 with value: 0.691811203956604.
# [I 2025-04-25 01:56:32,520] Trial 1 finished with value: 0.6895253658294678 and parameters: {'n_layers': 3, 'n_units_0': 256, 'activation_0': 'relu', 'dropout_rate_0': 0.2052169274621892, 'n_units_1': 64, 'activation_1': 'relu', 'dropout_rate_1': 0.42882106519882085, 'n_units_2': 256, 'activation_2': 'relu', 'dropout_rate_2': 0.2855828541676487, 'learning_rate': 0.0028516933807284225, 'batch_size': 64}. Best is trial 0 with value: 0.691811203956604.
# [I 2025-04-25 01:56:45,744] Trial 2 finished with value: 0.6568508744239807 and parameters: {'n_layers': 3, 'n_units_0': 64, 'activation_0': 'tanh', 'dropout_rate_0': 0.48492748330376473, 'n_units_1': 192, 'activation_1': 'tanh', 'dropout_rate_1': 0.3343834224248786, 'n_units_2': 192, 'activation_2': 'tanh', 'dropout_rate_2': 0.35120270005203746, 'learning_rate': 0.00961094827330056, 'batch_size': 32}. Best is trial 0 with value: 0.691811203956604.
# [I 2025-04-25 01:56:53,009] Trial 3 finished with value: 0.6906010508537292 and parameters: {'n_layers': 2, 'n_units_0': 128, 'activation_0': 'tanh', 'dropout_rate_0': 0.264311338443692, 'n_units_1': 192, 'activation_1': 'tanh', 'dropout_rate_1': 0.4957447436175977, 'learning_rate': 0.001510572190518105, 'batch_size': 64}. Best is trial 0 with value: 0.691811203956604.
# [I 2025-04-25 01:56:59,127] Trial 4 finished with value: 0.6911389231681824 and parameters: {'n_layers': 3, 'n_units_0': 256, 'activation_0': 'tanh', 'dropout_rate_0': 0.3290964736784792, 'n_units_1': 128, 'activation_1': 'tanh', 'dropout_rate_1': 0.2763256744572837, 'n_units_2': 192, 'activation_2': 'tanh', 'dropout_rate_2': 0.48373624201996224, 'learning_rate': 0.0005037378268504259, 'batch_size': 128}. Best is trial 0 with value: 0.691811203956604.
# [I 2025-04-25 01:57:11,056] Trial 5 finished with value: 0.6930213570594788 and parameters: {'n_layers': 2, 'n_units_0': 256, 'activation_0': 'relu', 'dropout_rate_0': 0.2250279836859621, 'n_units_1': 64, 'activation_1': 'tanh', 'dropout_rate_1': 0.2785980021119237, 'learning_rate': 0.0006242504017231766, 'batch_size': 32}. Best is trial 5 with value: 0.6930213570594788.
# [I 2025-04-25 01:57:18,521] Trial 6 finished with value: 0.6873739361763 and parameters: {'n_layers': 3, 'n_units_0': 128, 'activation_0': 'relu', 'dropout_rate_0': 0.49036760374612387, 'n_units_1': 64, 'activation_1': 'relu', 'dropout_rate_1': 0.3124694388435528, 'n_units_2': 192, 'activation_2': 'tanh', 'dropout_rate_2': 0.25407998254537806, 'learning_rate': 0.00023716253031267275, 'batch_size': 64}. Best is trial 5 with value: 0.6930213570594788.
# [I 2025-04-25 01:57:25,692] Trial 7 finished with value: 0.6891219615936279 and parameters: {'n_layers': 3, 'n_units_0': 256, 'activation_0': 'tanh', 'dropout_rate_0': 0.35610665528991714, 'n_units_1': 256, 'activation_1': 'tanh', 'dropout_rate_1': 0.24860764446847936, 'n_units_2': 192, 'activation_2': 'tanh', 'dropout_rate_2': 0.3794870854899306, 'learning_rate': 0.00103007734348033, 'batch_size': 128}. Best is trial 5 with value: 0.6930213570594788.
# [I 2025-04-25 01:57:36,693] Trial 8 finished with value: 0.6908699870109558 and parameters: {'n_layers': 1, 'n_units_0': 256, 'activation_0': 'relu', 'dropout_rate_0': 0.33028708646937144, 'learning_rate': 0.0006918905891122034, 'batch_size': 32}. Best is trial 5 with value: 0.6930213570594788.
# [I 2025-04-25 01:57:48,713] Trial 9 finished with value: 0.6915422677993774 and parameters: {'n_layers': 2, 'n_units_0': 64, 'activation_0': 'tanh', 'dropout_rate_0': 0.495006908973791, 'n_units_1': 64, 'activation_1': 'tanh', 'dropout_rate_1': 0.24583278136504025, 'learning_rate': 0.0007207795399005001, 'batch_size': 32}. Best is trial 5 with value: 0.6930213570594788.
# [I 2025-04-25 01:58:00,027] Trial 10 finished with value: 0.6908699870109558 and parameters: {'n_layers': 1, 'n_units_0': 192, 'activation_0': 'relu', 'dropout_rate_0': 0.2067869756218698, 'learning_rate': 0.00012151220187734997, 'batch_size': 32}. Best is trial 5 with value: 0.6930213570594788.
# [I 2025-04-25 01:58:07,655] Trial 11 finished with value: 0.6926180124282837 and parameters: {'n_layers': 2, 'n_units_0': 192, 'activation_0': 'relu', 'dropout_rate_0': 0.39117497556850855, 'n_units_1': 128, 'activation_1': 'tanh', 'dropout_rate_1': 0.3967711788251327, 'learning_rate': 0.00031116411943158447, 'batch_size': 64}. Best is trial 5 with value: 0.6930213570594788.
# [I 2025-04-25 01:58:15,206] Trial 12 finished with value: 0.691811203956604 and parameters: {'n_layers': 2, 'n_units_0': 192, 'activation_0': 'relu', 'dropout_rate_0': 0.41581228455934227, 'n_units_1': 128, 'activation_1': 'tanh', 'dropout_rate_1': 0.40047883204182366, 'learning_rate': 0.00027488717074804615, 'batch_size': 64}. Best is trial 5 with value: 0.6930213570594788.
# [I 2025-04-25 01:58:26,543] Trial 13 finished with value: 0.6926180124282837 and parameters: {'n_layers': 1, 'n_units_0': 192, 'activation_0': 'relu', 'dropout_rate_0': 0.4129476233812508, 'learning_rate': 0.0002792290043848373, 'batch_size': 32}. Best is trial 5 with value: 0.6930213570594788.
# [I 2025-04-25 01:58:31,139] Trial 14 finished with value: 0.6899287104606628 and parameters: {'n_layers': 2, 'n_units_0': 128, 'activation_0': 'relu', 'dropout_rate_0': 0.27665606399864107, 'n_units_1': 128, 'activation_1': 'relu', 'dropout_rate_1': 0.206016964679703, 'learning_rate': 0.00010536008817657887, 'batch_size': 128}. Best is trial 5 with value: 0.6930213570594788.
# [I 2025-04-25 01:58:38,106] Trial 15 finished with value: 0.6893908977508545 and parameters: {'n_layers': 2, 'n_units_0': 256, 'activation_0': 'relu', 'dropout_rate_0': 0.40996419810004575, 'n_units_1': 64, 'activation_1': 'tanh', 'dropout_rate_1': 0.39992190878330314, 'learning_rate': 0.0018673777513518177, 'batch_size': 64}. Best is trial 5 with value: 0.6930213570594788.
# [I 2025-04-25 01:58:49,528] Trial 16 finished with value: 0.6920801401138306 and parameters: {'n_layers': 1, 'n_units_0': 192, 'activation_0': 'relu', 'dropout_rate_0': 0.2758046751235219, 'learning_rate': 0.0004391485162584229, 'batch_size': 32}. Best is trial 5 with value: 0.6930213570594788.
# [I 2025-04-25 01:59:02,490] Trial 17 finished with value: 0.6840123534202576 and parameters: {'n_layers': 2, 'n_units_0': 256, 'activation_0': 'relu', 'dropout_rate_0': 0.4483463005323743, 'n_units_1': 128, 'activation_1': 'tanh', 'dropout_rate_1': 0.37698850850425525, 'learning_rate': 0.004858002116419148, 'batch_size': 32}. Best is trial 5 with value: 0.6930213570594788.
# [I 2025-04-25 01:59:08,791] Trial 18 finished with value: 0.691811203956604 and parameters: {'n_layers': 1, 'n_units_0': 192, 'activation_0': 'relu', 'dropout_rate_0': 0.24339064085386852, 'learning_rate': 0.00022595672160575044, 'batch_size': 64}. Best is trial 5 with value: 0.6930213570594788.
# [I 2025-04-25 01:59:13,077] Trial 19 finished with value: 0.6872394680976868 and parameters: {'n_layers': 2, 'n_units_0': 128, 'activation_0': 'relu', 'dropout_rate_0': 0.3752459843245723, 'n_units_1': 64, 'activation_1': 'relu', 'dropout_rate_1': 0.4651163382290089, 'learning_rate': 0.0004569894999536748, 'batch_size': 128}. Best is trial 5 with value: 0.6930213570594788.
# Best Trial:
# FrozenTrial(number=5, state=TrialState.COMPLETE, values=[0.6930213570594788], datetime_start=datetime.datetime(2025, 4, 25, 1, 56, 59, 135874), datetime_complete=datetime.datetime(2025, 4, 25, 1, 57, 11, 35623), params={'n_layers': 2, 'n_units_0': 256, 'activation_0': 'relu', 'dropout_rate_0': 0.2250279836859621, 'n_units_1': 64, 'activation_1': 'tanh', 'dropout_rate_1': 0.2785980021119237, 'learning_rate': 0.0006242504017231766, 'batch_size': 32}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'n_layers': IntDistribution(high=3, log=False, low=1, step=1), 'n_units_0': IntDistribution(high=256, log=False, low=64, step=64), 'activation_0': CategoricalDistribution(choices=('relu', 'tanh')), 'dropout_rate_0': FloatDistribution(high=0.5, log=False, low=0.2, step=None), 'n_units_1': IntDistribution(high=256, log=False, low=64, step=64), 'activation_1': CategoricalDistribution(choices=('relu', 'tanh')), 'dropout_rate_1': FloatDistribution(high=0.5, log=False, low=0.2, step=None), 'learning_rate': FloatDistribution(high=0.01, log=True, low=0.0001, step=None), 'batch_size': CategoricalDistribution(choices=(32, 64, 128))}, trial_id=98, value=None)
# Best Hyperparameters:
# {'n_layers': 2, 'n_units_0': 256, 'activation_0': 'relu', 'dropout_rate_0': 0.2250279836859621, 'n_units_1': 64, 'activation_1': 'tanh', 'dropout_rate_1': 0.2785980021119237, 'learning_rate': 0.0006242504017231766, 'batch_size': 32}

# %%
# Load Optuna study
study = optuna.load_study(
    study_name="DNN_diseases_symptoms_dropextremelymore1000withSMOTE_study",
    storage="sqlite:///C:/Users/khiew/Downloads/dnn.db"
)

# Get best parameters
best_params = study.best_trial.params

# Rebuild model using best parameters
best_model = keras.Sequential()
best_model.add(layers.Input(shape=(input_dim,)))

for i in range(best_params['n_layers']):
    best_model.add(layers.Dense(best_params[f'n_units_{i}'], activation=best_params[f'activation_{i}']))
    best_model.add(layers.Dropout(best_params[f'dropout_rate_{i}']))

best_model.add(layers.Dense(num_classes, activation='softmax'))

best_model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=best_params['learning_rate']),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# Fit the model and save training history
history = best_model.fit(
    X_train_resampled,
    y_train_resampled,
    epochs=20,
    batch_size=best_params['batch_size'],
    validation_split=0.2,
    verbose=1
)

# ===========================
# Plotting Training Lifecycle
# ===========================

plt.figure(figsize=(12, 5))

# Plot Accuracy
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy', marker='o')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy', marker='s')
plt.title('Model Accuracy over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

# Plot Loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss', marker='o')
plt.plot(history.history['val_loss'], label='Validation Loss', marker='s')
plt.title('Model Loss over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()
# Out:
# Epoch 1/20
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.4299 - loss: 2.3133 - val_accuracy: 0.6802 - val_loss: 0.9180
# Epoch 2/20
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6503 - loss: 1.0008 - val_accuracy: 0.6855 - val_loss: 0.8515
# Epoch 3/20
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6658 - loss: 0.9474 - val_accuracy: 0.6891 - val_loss: 0.8424
# Epoch 4/20
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6737 - loss: 0.9075 - val_accuracy: 0.6911 - val_loss: 0.8379
# Epoch 5/20
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6738 - loss: 0.8951 - val_accuracy: 0.6886 - val_loss: 0.8288
# Epoch 6/20
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6746 - loss: 0.8991 - val_accuracy: 0.6870 - val_loss: 0.8276
# Epoch 7/20
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6704 - loss: 0.8934 - val_accuracy: 0.6875 - val_loss: 0.8341
# Epoch 8/20
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6729 - loss: 0.8932 - val_accuracy: 0.6862 - val_loss: 0.8295
# Epoch 9/20
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6744 - loss: 0.8867 - val_accuracy: 0.6907 - val_loss: 0.8220
# Epoch 10/20
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6730 - loss: 0.8868 - val_accuracy: 0.6859 - val_loss: 0.8265
# Epoch 11/20
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6737 - loss: 0.8841 - val_accuracy: 0.6867 - val_loss: 0.8228
# Epoch 12/20
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6777 - loss: 0.8701 - val_accuracy: 0.6860 - val_loss: 0.8267
# Epoch 13/20
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6760 - loss: 0.8750 - val_accuracy: 0.6909 - val_loss: 0.8229
# Epoch 14/20
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6717 - loss: 0.8798 - val_accuracy: 0.6860 - val_loss: 0.8243
# Epoch 15/20
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6778 - loss: 0.8742 - val_accuracy: 0.6915 - val_loss: 0.8223
# Epoch 16/20
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6751 - loss: 0.8857 - val_accuracy: 0.6874 - val_loss: 0.8189
# Epoch 17/20
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6810 - loss: 0.8686 - val_accuracy: 0.6910 - val_loss: 0.8226
# Epoch 18/20
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6752 - loss: 0.8745 - val_accuracy: 0.6867 - val_loss: 0.8189
# Epoch 19/20
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6772 - loss: 0.8626 - val_accuracy: 0.6884 - val_loss: 0.8208
# Epoch 20/20
# 930/930 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6783 - loss: 0.8658 - val_accuracy: 0.6797 - val_loss: 0.8232

# %%
from sklearn.metrics import classification_report

y_pred_test = np.argmax(best_model.predict(X_test), axis=1)
print("Classification Report on Test Set:")
print(classification_report(y_test, y_pred_test, target_names=label_encoder.classes_))
# Out:
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 0s 655us/step
# Classification Report on Test Set:
#                                     precision    recall  f1-score   support
#
#                acute bronchiolitis       0.72      0.82      0.77       247
#                   acute bronchitis       0.73      0.69      0.71       249
#                 acute pancreatitis       1.00      0.70      0.83       257
#                            anxiety       0.95      0.86      0.90       237
#               arthritis of the hip       0.92      0.55      0.69       236
# benign prostatic hyperplasia (bph)       0.00      0.00      0.00       238
#                           bursitis       0.44      0.78      0.56       244
#                      cholecystitis       0.65      0.79      0.72       233
#     complex regional pain syndrome       0.72      0.22      0.34       258
#                         concussion       0.76      0.85      0.80       217
#      conjunctivitis due to allergy       0.73      0.88      0.80       210
#                           cystitis       0.73      0.71      0.72       252
#                      dental caries       0.93      0.89      0.91       262
#                     diverticulitis       0.94      0.62      0.75       240
#                             eczema       1.00      0.65      0.79       218
#                        esophagitis       0.98      0.88      0.93       250
#       fungal infection of the hair       0.83      0.93      0.88       227
#        gastrointestinal hemorrhage       0.66      0.82      0.73       247
#                               gout       0.28      1.00      0.44       252
#                       hypoglycemia       0.82      0.85      0.83       246
#         infectious gastroenteritis       0.43      0.30      0.35       252
#                  injury to the arm       0.74      0.47      0.58       249
#                  injury to the leg       0.74      0.53      0.62       232
#                      liver disease       0.95      0.82      0.88       233
#                    marijuana abuse       0.95      0.86      0.90       254
#      noninfectious gastroenteritis       0.44      0.53      0.48       246
#                      nose disorder       0.74      0.77      0.76       230
#      obstructive sleep apnea (osa)       0.86      0.86      0.86       235
#          peripheral nerve disorder       0.69      0.51      0.59       236
#                          pneumonia       0.95      0.63      0.76       258
#                    spinal stenosis       0.51      0.53      0.52       245
#                        spondylosis       0.54      0.60      0.57       254
#               spontaneous abortion       0.82      0.54      0.65       229
#                   sprain or strain       0.58      0.78      0.67       237
#                       strep throat       1.00      0.91      0.95       264
#                       vaginal cyst       0.52      0.87      0.66       243
#                         vulvodynia       0.77      0.55      0.64       233
#
#                           accuracy                           0.69      8950
#                          macro avg       0.73      0.69      0.69      8950
#                       weighted avg       0.73      0.69      0.69      8950
# c:\Users\khiew\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\khiew\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\khiew\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
