# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from imblearn.over_sampling import SMOTE
import optuna
import matplotlib.pyplot as plt

# %%
# Load the dataset
df = pd.read_csv(r'C:\Users\khiew\Downloads\FYP Augmented (Secondly) Dataset.csv')

# %%
# Drop diseases with less than 750 instances
disease_counts = df['diseases'].value_counts()
valid_diseases = disease_counts[disease_counts >= 750].index
df = df[df['diseases'].isin(valid_diseases)]

# Assuming that the target variable is 'diseases' and all other variables are input features
X = df.drop('diseases', axis=1)
y = df['diseases']

# Encode the target variable (diseases) if it's a categorical variable
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42)
num_classes = len(np.unique(y_train))
input_dim = X_train.shape[1]
print("Number of remaining classes in training set:", len(np.unique(y_train)))
print("Number of rows left:", len(df))
# Out:
# Number of remaining classes in training set: 114
# Number of rows left: 114312

# %%
# Apply SMOTE for class balancing in the training set
smote = SMOTE(random_state=42)
X_train_resampled, y_train_resampled = smote.fit_resample(X_train, y_train)

# Print the new class distribution after SMOTE
print("Class distribution after SMOTE:")
print(pd.Series(y_train_resampled).value_counts())
print("Number of remaining classes in training set:", len(np.unique(y_train_resampled)))
# Print the number of rows in the resampled training set
print("Number of rows in the resampled training set:", len(X_train_resampled))
# Out:
# Class distribution after SMOTE:
# 20     1002
# 9      1002
# 66     1002
# 80     1002
# 1      1002
#        ...
# 40     1002
# 106    1002
# 54     1002
# 102    1002
# 88     1002
# Name: count, Length: 114, dtype: int64
# Number of remaining classes in training set: 114
# Number of rows in the resampled training set: 114228

# %%
# Apply SMOTE for class balancing in the training set
smote = SMOTE(random_state=42)
X_train_resampled, y_train_resampled = smote.fit_resample(X_train, y_train)

# Print the new class distribution after SMOTE
print("Class distribution after SMOTE:")
print(pd.Series(y_train_resampled).value_counts())
print("Number of remaining classes in training set:", len(np.unique(y_train_resampled)))
# Print the number of rows in the resampled training set
print("Number of rows in the resampled training set:", len(X_train_resampled))
# Out:
# Class distribution after SMOTE:
# 20     1002
# 9      1002
# 66     1002
# 80     1002
# 1      1002
#        ...
# 40     1002
# 106    1002
# 54     1002
# 102    1002
# 88     1002
# Name: count, Length: 114, dtype: int64
# Number of remaining classes in training set: 114
# Number of rows in the resampled training set: 114228

# %%
# Optuna objective function
def objective(trial):
    model = keras.Sequential()
    model.add(layers.Input(shape=(input_dim,)))

    # Suggest hyperparameters
    n_layers = trial.suggest_int('n_layers', 1, 3)
    for i in range(n_layers):
        num_units = trial.suggest_int(f'n_units_{i}', 64, 256, step=64)
        activation = trial.suggest_categorical(f'activation_{i}', ['relu', 'tanh'])
        model.add(layers.Dense(num_units, activation=activation))
        dropout_rate = trial.suggest_float(f'dropout_rate_{i}', 0.2, 0.5)
        model.add(layers.Dropout(dropout_rate))

    model.add(layers.Dense(num_classes, activation='softmax'))

    learning_rate = trial.suggest_float('learning_rate', 1e-4, 1e-2, log=True)
    optimizer = keras.optimizers.Adam(learning_rate=learning_rate)

    model.compile(optimizer=optimizer,
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])

    history = model.fit(X_train_resampled, y_train_resampled,
                        validation_split=0.2,
                        epochs=10,
                        batch_size=trial.suggest_categorical('batch_size', [32, 64, 128]),
                        verbose=0)

    val_accuracy = max(history.history['val_accuracy'])
    return val_accuracy

# %%
# Create Optuna study for optimization with persistent storage
study = optuna.create_study(
    direction='maximize',  # Assuming you are maximizing accuracy
    study_name="DNN_diseases_symptoms_dropextremelymore750withSMOTE_secondaugmented_study", 
    storage=r"sqlite:///C:/Users/khiew/Downloads/dnn.db", 
    load_if_exists=True  # Load the study if it already exists, to resume from the last trial
)

# Optimize the study with your objective function, you can adjust the n_trials as needed
study.optimize(objective, n_trials=20)
# Print the best trial and hyperparameters
print("\nBest Trial:")
print(study.best_trial)
print("Best Hyperparameters:")
print(study.best_trial.params)
# Out:
# [I 2025-04-25 01:29:04,654] Using an existing study with name 'DNN_diseases_symptoms_dropextremelymore750withSMOTE_secondaugmented_study' instead of creating a new one.
# [I 2025-04-25 01:30:09,100] Trial 7 finished with value: 0.6780617833137512 and parameters: {'n_layers': 2, 'n_units_0': 192, 'activation_0': 'relu', 'dropout_rate_0': 0.2038964495245399, 'n_units_1': 64, 'activation_1': 'tanh', 'dropout_rate_1': 0.4388557651883983, 'learning_rate': 0.0002362280877467302, 'batch_size': 32}. Best is trial 7 with value: 0.6780617833137512.
# [I 2025-04-25 01:31:16,430] Trial 8 finished with value: 0.6806005239486694 and parameters: {'n_layers': 3, 'n_units_0': 256, 'activation_0': 'tanh', 'dropout_rate_0': 0.24950448918312634, 'n_units_1': 64, 'activation_1': 'tanh', 'dropout_rate_1': 0.23277565410249001, 'n_units_2': 192, 'activation_2': 'tanh', 'dropout_rate_2': 0.3078610874873298, 'learning_rate': 0.00024718525973667214, 'batch_size': 32}. Best is trial 8 with value: 0.6806005239486694.
# [I 2025-04-25 01:31:33,964] Trial 9 finished with value: 0.6758732199668884 and parameters: {'n_layers': 1, 'n_units_0': 128, 'activation_0': 'relu', 'dropout_rate_0': 0.43045697433446084, 'learning_rate': 0.00519532661339308, 'batch_size': 128}. Best is trial 8 with value: 0.6806005239486694.
# [I 2025-04-25 01:32:39,135] Trial 10 finished with value: 0.6688260436058044 and parameters: {'n_layers': 2, 'n_units_0': 192, 'activation_0': 'tanh', 'dropout_rate_0': 0.225012850740711, 'n_units_1': 192, 'activation_1': 'tanh', 'dropout_rate_1': 0.4370890251396701, 'learning_rate': 0.0010537077558524233, 'batch_size': 32}. Best is trial 8 with value: 0.6806005239486694.
# [I 2025-04-25 01:33:16,284] Trial 11 finished with value: 0.6622603535652161 and parameters: {'n_layers': 3, 'n_units_0': 128, 'activation_0': 'tanh', 'dropout_rate_0': 0.23645618825666423, 'n_units_1': 128, 'activation_1': 'tanh', 'dropout_rate_1': 0.3844802448524258, 'n_units_2': 64, 'activation_2': 'tanh', 'dropout_rate_2': 0.41941795576526797, 'learning_rate': 0.002497088858111169, 'batch_size': 64}. Best is trial 8 with value: 0.6806005239486694.
# [I 2025-04-25 01:33:43,933] Trial 12 finished with value: 0.6841460466384888 and parameters: {'n_layers': 1, 'n_units_0': 64, 'activation_0': 'tanh', 'dropout_rate_0': 0.22095463003311197, 'learning_rate': 0.000455511404499834, 'batch_size': 64}. Best is trial 12 with value: 0.6841460466384888.
# [I 2025-04-25 01:34:23,909] Trial 13 finished with value: 0.6635296940803528 and parameters: {'n_layers': 3, 'n_units_0': 128, 'activation_0': 'relu', 'dropout_rate_0': 0.3304006983305603, 'n_units_1': 192, 'activation_1': 'relu', 'dropout_rate_1': 0.3802794206231317, 'n_units_2': 64, 'activation_2': 'tanh', 'dropout_rate_2': 0.46711209993931, 'learning_rate': 0.0005423225553393567, 'batch_size': 64}. Best is trial 12 with value: 0.6841460466384888.
# [I 2025-04-25 01:35:09,687] Trial 14 finished with value: 0.6825702786445618 and parameters: {'n_layers': 2, 'n_units_0': 256, 'activation_0': 'relu', 'dropout_rate_0': 0.3577737153179627, 'n_units_1': 192, 'activation_1': 'relu', 'dropout_rate_1': 0.2621589094393506, 'learning_rate': 0.00044087740157438274, 'batch_size': 64}. Best is trial 12 with value: 0.6841460466384888.
# [I 2025-04-25 01:35:33,365] Trial 15 finished with value: 0.6815197467803955 and parameters: {'n_layers': 1, 'n_units_0': 256, 'activation_0': 'tanh', 'dropout_rate_0': 0.43483279416515885, 'learning_rate': 0.001557119833800002, 'batch_size': 128}. Best is trial 12 with value: 0.6841460466384888.
# [I 2025-04-25 01:36:27,344] Trial 16 finished with value: 0.682657778263092 and parameters: {'n_layers': 1, 'n_units_0': 128, 'activation_0': 'tanh', 'dropout_rate_0': 0.3534191723347465, 'learning_rate': 0.00015564772402892925, 'batch_size': 32}. Best is trial 12 with value: 0.6841460466384888.
# [I 2025-04-25 01:36:54,517] Trial 17 finished with value: 0.6540750861167908 and parameters: {'n_layers': 1, 'n_units_0': 64, 'activation_0': 'tanh', 'dropout_rate_0': 0.3122740027139952, 'learning_rate': 0.00010107478862824166, 'batch_size': 64}. Best is trial 12 with value: 0.6841460466384888.
# [I 2025-04-25 01:37:43,796] Trial 18 finished with value: 0.6679943799972534 and parameters: {'n_layers': 1, 'n_units_0': 64, 'activation_0': 'tanh', 'dropout_rate_0': 0.3794724370275761, 'learning_rate': 0.00012574253483736412, 'batch_size': 32}. Best is trial 12 with value: 0.6841460466384888.
# [I 2025-04-25 01:38:11,134] Trial 19 finished with value: 0.6742974519729614 and parameters: {'n_layers': 1, 'n_units_0': 64, 'activation_0': 'tanh', 'dropout_rate_0': 0.49593012161924943, 'learning_rate': 0.0003640680166533598, 'batch_size': 64}. Best is trial 12 with value: 0.6841460466384888.
# [I 2025-04-25 01:39:02,289] Trial 20 finished with value: 0.6774927973747253 and parameters: {'n_layers': 1, 'n_units_0': 64, 'activation_0': 'tanh', 'dropout_rate_0': 0.29718528871842115, 'learning_rate': 0.00019879628628872236, 'batch_size': 32}. Best is trial 12 with value: 0.6841460466384888.
# [I 2025-04-25 01:39:30,275] Trial 21 finished with value: 0.6822638511657715 and parameters: {'n_layers': 2, 'n_units_0': 128, 'activation_0': 'tanh', 'dropout_rate_0': 0.2826773316152908, 'n_units_1': 256, 'activation_1': 'relu', 'dropout_rate_1': 0.4952919323373667, 'learning_rate': 0.0007303860934928572, 'batch_size': 128}. Best is trial 12 with value: 0.6841460466384888.
# [I 2025-04-25 01:40:03,821] Trial 22 finished with value: 0.6436575055122375 and parameters: {'n_layers': 1, 'n_units_0': 192, 'activation_0': 'tanh', 'dropout_rate_0': 0.3925813603436088, 'learning_rate': 0.008467491480346945, 'batch_size': 64}. Best is trial 12 with value: 0.6841460466384888.
# [I 2025-04-25 01:41:08,156] Trial 23 finished with value: 0.681082010269165 and parameters: {'n_layers': 2, 'n_units_0': 64, 'activation_0': 'tanh', 'dropout_rate_0': 0.2718112152742533, 'n_units_1': 256, 'activation_1': 'relu', 'dropout_rate_1': 0.30495911275299903, 'learning_rate': 0.00015531975077058853, 'batch_size': 32}. Best is trial 12 with value: 0.6841460466384888.
# [I 2025-04-25 01:41:39,371] Trial 24 finished with value: 0.682657778263092 and parameters: {'n_layers': 1, 'n_units_0': 128, 'activation_0': 'tanh', 'dropout_rate_0': 0.35115647689897345, 'learning_rate': 0.0002936437330039011, 'batch_size': 64}. Best is trial 12 with value: 0.6841460466384888.
# [I 2025-04-25 01:42:24,719] Trial 25 finished with value: 0.6828766465187073 and parameters: {'n_layers': 1, 'n_units_0': 64, 'activation_0': 'relu', 'dropout_rate_0': 0.41328959952153066, 'learning_rate': 0.000984121852171222, 'batch_size': 32}. Best is trial 12 with value: 0.6841460466384888.
# [I 2025-04-25 01:42:35,985] Trial 26 finished with value: 0.6618226170539856 and parameters: {'n_layers': 2, 'n_units_0': 64, 'activation_0': 'relu', 'dropout_rate_0': 0.49192335307361146, 'n_units_1': 128, 'activation_1': 'relu', 'dropout_rate_1': 0.3036871469658123, 'learning_rate': 0.0023709573918865253, 'batch_size': 128}. Best is trial 12 with value: 0.6841460466384888.
# Best Trial:
# FrozenTrial(number=12, state=TrialState.COMPLETE, values=[0.6841460466384888], datetime_start=datetime.datetime(2025, 4, 25, 1, 33, 16, 296005), datetime_complete=datetime.datetime(2025, 4, 25, 1, 33, 43, 903645), params={'n_layers': 1, 'n_units_0': 64, 'activation_0': 'tanh', 'dropout_rate_0': 0.22095463003311197, 'learning_rate': 0.000455511404499834, 'batch_size': 64}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'n_layers': IntDistribution(high=3, log=False, low=1, step=1), 'n_units_0': IntDistribution(high=256, log=False, low=64, step=64), 'activation_0': CategoricalDistribution(choices=('relu', 'tanh')), 'dropout_rate_0': FloatDistribution(high=0.5, log=False, low=0.2, step=None), 'learning_rate': FloatDistribution(high=0.01, log=True, low=0.0001, step=None), 'batch_size': CategoricalDistribution(choices=(32, 64, 128))}, trial_id=33, value=None)
# Best Hyperparameters:
# {'n_layers': 1, 'n_units_0': 64, 'activation_0': 'tanh', 'dropout_rate_0': 0.22095463003311197, 'learning_rate': 0.000455511404499834, 'batch_size': 64}

# %%
# Load Optuna study
study = optuna.load_study(
    study_name="DNN_diseases_symptoms_dropextremelymore750withSMOTE_secondaugmented_study",
    storage="sqlite:///C:/Users/khiew/Downloads/dnn.db"
)

# Get best parameters
best_params = study.best_trial.params

# Rebuild model using best parameters
best_model = keras.Sequential()
best_model.add(layers.Input(shape=(input_dim,)))

for i in range(best_params['n_layers']):
    best_model.add(layers.Dense(best_params[f'n_units_{i}'], activation=best_params[f'activation_{i}']))
    best_model.add(layers.Dropout(best_params[f'dropout_rate_{i}']))

best_model.add(layers.Dense(num_classes, activation='softmax'))

best_model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=best_params['learning_rate']),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# Fit the model and save training history
history = best_model.fit(
    X_train_resampled,
    y_train_resampled,
    epochs=20,
    batch_size=best_params['batch_size'],
    validation_split=0.2,
    verbose=1
)

# ===========================
# Plotting Training Lifecycle
# ===========================

plt.figure(figsize=(12, 5))

# Plot Accuracy
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy', marker='o')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy', marker='s')
plt.title('Model Accuracy over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

# Plot Loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss', marker='o')
plt.plot(history.history['val_loss'], label='Validation Loss', marker='s')
plt.title('Model Loss over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()
# Out:
# Epoch 1/20
# 1428/1428 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.2850 - loss: 3.6913 - val_accuracy: 0.6013 - val_loss: 1.6175
# Epoch 2/20
# 1428/1428 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.6441 - loss: 1.3439 - val_accuracy: 0.6420 - val_loss: 1.1475
# Epoch 3/20
# 1428/1428 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.6742 - loss: 1.0301 - val_accuracy: 0.6615 - val_loss: 1.0165
# Epoch 4/20
# 1428/1428 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.6806 - loss: 0.9364 - val_accuracy: 0.6718 - val_loss: 0.9550
# Epoch 5/20
# 1428/1428 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.6884 - loss: 0.8863 - val_accuracy: 0.6754 - val_loss: 0.9224
# Epoch 6/20
# 1428/1428 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.6875 - loss: 0.8661 - val_accuracy: 0.6769 - val_loss: 0.9080
# Epoch 7/20
# 1428/1428 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.6912 - loss: 0.8479 - val_accuracy: 0.6789 - val_loss: 0.8974
# Epoch 8/20
# 1428/1428 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.6926 - loss: 0.8400 - val_accuracy: 0.6776 - val_loss: 0.8873
# Epoch 9/20
# 1428/1428 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.6938 - loss: 0.8296 - val_accuracy: 0.6807 - val_loss: 0.8771
# Epoch 10/20
# 1428/1428 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.6913 - loss: 0.8329 - val_accuracy: 0.6778 - val_loss: 0.8762
# Epoch 11/20
# 1428/1428 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.6909 - loss: 0.8254 - val_accuracy: 0.6801 - val_loss: 0.8754
# Epoch 12/20
# 1428/1428 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.6929 - loss: 0.8206 - val_accuracy: 0.6823 - val_loss: 0.8710
# Epoch 13/20
# 1428/1428 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.6953 - loss: 0.8132 - val_accuracy: 0.6813 - val_loss: 0.8696
# Epoch 14/20
# 1428/1428 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.6941 - loss: 0.8151 - val_accuracy: 0.6779 - val_loss: 0.8692
# Epoch 15/20
# 1428/1428 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.6939 - loss: 0.8100 - val_accuracy: 0.6839 - val_loss: 0.8652
# Epoch 16/20
# 1428/1428 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.6923 - loss: 0.8157 - val_accuracy: 0.6800 - val_loss: 0.8649
# Epoch 17/20
# 1428/1428 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.6951 - loss: 0.8064 - val_accuracy: 0.6843 - val_loss: 0.8608
# Epoch 18/20
# 1428/1428 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.6976 - loss: 0.8067 - val_accuracy: 0.6827 - val_loss: 0.8627
# Epoch 19/20
# 1428/1428 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.6954 - loss: 0.8020 - val_accuracy: 0.6782 - val_loss: 0.8621
# Epoch 20/20
# 1428/1428 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.7012 - loss: 0.7948 - val_accuracy: 0.6862 - val_loss: 0.8586

# %%
from sklearn.metrics import classification_report

y_pred_test = np.argmax(best_model.predict(X_test), axis=1)
print("Classification Report on Test Set:")
print(classification_report(y_test, y_pred_test, target_names=label_encoder.classes_))
# Out:
# 715/715 ━━━━━━━━━━━━━━━━━━━━ 0s 595us/step
# Classification Report on Test Set:
#                                               precision    recall  f1-score   support
#
#                            actinic keratosis       0.26      0.61      0.37       192
#                          acute bronchiolitis       0.74      0.78      0.76       245
#                             acute bronchitis       0.69      0.59      0.64       275
#                           acute bronchospasm       0.75      0.57      0.65       174
#                          acute kidney injury       0.97      0.91      0.94       202
#                           acute pancreatitis       1.00      0.74      0.85       245
#                              acute sinusitis       0.63      0.53      0.57       188
#                        acute stress reaction       1.00      0.81      0.90       158
#                                      allergy       0.95      0.72      0.82       175
#                                       angina       0.68      0.94      0.79       178
#                                      anxiety       0.76      0.89      0.82       250
#                                 appendicitis       0.92      0.53      0.67       188
#                         arthritis of the hip       0.95      0.88      0.91       249
#                                       asthma       0.96      0.53      0.69       159
#           benign prostatic hyperplasia (bph)       0.94      0.90      0.92       261
#                                  blepharitis       0.00      0.00      0.00       152
#                            brachial neuritis       0.52      0.94      0.67       180
#                                     bursitis       0.84      0.80      0.81       249
#                       carpal tunnel syndrome       0.88      0.49      0.63       190
#                                cholecystitis       0.53      0.89      0.66       226
#                            chronic back pain       0.69      0.80      0.74       170
#                         chronic constipation       0.69      0.83      0.76       199
# chronic obstructive pulmonary disease (copd)       0.67      0.77      0.72       176
#                                  common cold       0.62      0.37      0.46       167
#               complex regional pain syndrome       0.87      0.75      0.80       251
#                                   concussion       0.98      0.94      0.96       254
#                               conjunctivitis       0.40      0.75      0.52       172
#                conjunctivitis due to allergy       0.90      0.81      0.85       231
#                           contact dermatitis       0.61      0.59      0.60       194
#                             cornea infection       0.94      0.68      0.79       183
#                                        croup       0.47      0.62      0.53       192
#                                     cystitis       0.87      0.68      0.76       224
#                    degenerative disc disease       0.73      0.69      0.71       172
#                                dental caries       0.81      0.81      0.81       245
#                                   depression       1.00      0.66      0.80       200
#                     developmental disability       0.70      0.87      0.78       188
#                                  diaper rash       0.89      0.86      0.88       175
#                               diverticulitis       0.68      0.70      0.69       259
#                                drug reaction       1.00      0.93      0.97       184
#                     dry eye of unknown cause       0.29      0.77      0.42       184
#                              ear drum damage       0.48      0.85      0.62       164
#                                       eczema       0.83      0.44      0.58       212
#                                  esophagitis       1.00      0.92      0.95       254
#   eustachian tube dysfunction (ear disorder)       0.70      0.84      0.76       184
#                          fracture of the rib       0.93      0.94      0.93       182
#                 fungal infection of the hair       1.00      0.44      0.61       242
#                                    gallstone       0.92      0.50      0.65       176
#                  gastrointestinal hemorrhage       0.71      0.81      0.76       242
#                                         gout       0.72      0.76      0.74       237
#                                  gum disease       0.81      0.66      0.73       182
#                                 heart attack       0.89      0.90      0.89       177
#                                heart failure       0.70      0.81      0.75       181
#                                  hemorrhoids       0.74      0.94      0.83       178
#                               herniated disk       0.59      0.58      0.58       171
#                                hiatal hernia       0.96      0.82      0.89       177
#                       hyperemesis gravidarum       0.67      0.75      0.71       163
#                   hypertensive heart disease       0.99      0.76      0.86       169
#                                 hypoglycemia       1.00      0.90      0.95       250
#            idiopathic excessive menstruation       0.55      0.80      0.65       174
#         idiopathic irregular menstrual cycle       0.35      0.90      0.51       181
#              idiopathic painful menstruation       0.55      0.77      0.64       163
#                   infectious gastroenteritis       0.46      0.43      0.44       258
#                            injury to the arm       0.61      0.92      0.73       251
#                            injury to the leg       0.79      0.72      0.75       238
#                          injury to the trunk       0.83      0.76      0.79       164
#                       ischemic heart disease       0.89      0.81      0.85       182
#                                 kidney stone       0.74      0.60      0.66       205
#                                liver disease       0.95      0.89      0.92       234
#                         macular degeneration       0.07      0.16      0.10       187
#                              marijuana abuse       0.77      0.70      0.74       245
#                           multiple sclerosis       0.92      0.89      0.91       198
#                                     neurosis       0.85      0.50      0.63       175
#                noninfectious gastroenteritis       0.37      0.31      0.34       221
#                                nose disorder       0.98      0.54      0.69       216
#                obstructive sleep apnea (osa)       0.91      0.95      0.93       268
#                               osteoarthritis       0.78      0.72      0.75       178
#               otitis externa (swimmer's ear)       0.62      0.64      0.63       202
#                                 otitis media       0.54      0.56      0.55       180
#                      pain after an operation       0.96      0.92      0.94       180
#                               panic disorder       0.93      0.72      0.81       189
#                  pelvic inflammatory disease       1.00      0.79      0.88       191
#                    peripheral nerve disorder       0.81      0.92      0.86       234
#                         personality disorder       0.27      0.33      0.29       154
#                                    pneumonia       0.93      0.54      0.68       238
#                     problem during pregnancy       0.74      0.82      0.78       173
#                                    psoriasis       1.00      0.53      0.69       192
#                           psychotic disorder       0.79      0.40      0.53       177
#                           pulmonary embolism       1.00      0.82      0.90       184
#                               pyelonephritis       0.74      0.62      0.67       190
#                      pyogenic skin infection       0.98      0.93      0.96       183
#                              rectal disorder       0.79      0.70      0.74       177
#                                schizophrenia       0.37      0.71      0.49       183
#               seasonal allergies (hay fever)       0.69      0.73      0.71       179
#                               sebaceous cyst       0.32      0.88      0.47       164
#                        seborrheic dermatitis       0.37      0.55      0.44       169
#                         seborrheic keratosis       0.31      0.03      0.05       190
#                                       sepsis       1.00      0.90      0.95       178
#                           sickle cell crisis       1.00      0.96      0.98       192
#                            sinus bradycardia       0.89      0.80      0.85       191
#                   skin pigmentation disorder       0.31      0.07      0.11       200
#                                   skin polyp       0.33      0.32      0.32       180
#                 smoking or tobacco addiction       0.69      0.89      0.78       175
#                              spinal stenosis       0.90      0.65      0.76       237
#                                  spondylosis       0.98      0.65      0.78       255
#                         spontaneous abortion       0.82      0.57      0.67       210
#                             sprain or strain       0.86      0.79      0.82       252
#                                 strep throat       1.00      0.92      0.96       253
#                                         stye       0.70      0.85      0.77       188
#           temporary or benign blood in urine       0.63      0.93      0.75       149
#                         threatened pregnancy       0.74      0.43      0.55       182
#                      urinary tract infection       0.78      0.81      0.80       166
#                                 vaginal cyst       0.76      0.21      0.33       270
#                                    vaginitis       0.85      0.74      0.79       195
#                                   vulvodynia       0.82      0.81      0.81       226
#
#                                     accuracy                           0.71     22863
#                                    macro avg       0.75      0.70      0.70     22863
#                                 weighted avg       0.76      0.71      0.71     22863
# c:\Users\khiew\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\khiew\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\khiew\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
