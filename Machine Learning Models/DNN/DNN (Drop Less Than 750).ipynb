# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from imblearn.over_sampling import SMOTE
import optuna
import matplotlib.pyplot as plt

# %%
# Load the dataset
df = pd.read_csv(r'C:\Users\khiew\Downloads\FYP Reduced Dataset.csv')

# %%
# Drop diseases with less than 1000 instances
disease_counts = df['diseases'].value_counts()
valid_diseases = disease_counts[disease_counts >= 750].index
df = df[df['diseases'].isin(valid_diseases)]

# Assuming that the target variable is 'diseases' and all other variables are input features
X = df.drop('diseases', axis=1)
y = df['diseases']

# Encode the target variable (diseases) if it's a categorical variable
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42)
num_classes = len(np.unique(y_train))
input_dim = X_train.shape[1]
print("Number of remaining classes in training set:", len(np.unique(y_train)))
print("Number of rows left:", len(df))
# Out:
# Number of remaining classes in training set: 114
# Number of rows left: 114312

# %%
# Optuna objective function
def objective(trial):
    model = keras.Sequential()
    model.add(layers.Input(shape=(input_dim,)))

    # Suggest hyperparameters
    n_layers = trial.suggest_int('n_layers', 1, 3)
    for i in range(n_layers):
        num_units = trial.suggest_int(f'n_units_{i}', 64, 256, step=64)
        activation = trial.suggest_categorical(f'activation_{i}', ['relu', 'tanh'])
        model.add(layers.Dense(num_units, activation=activation))
        dropout_rate = trial.suggest_float(f'dropout_rate_{i}', 0.2, 0.5)
        model.add(layers.Dropout(dropout_rate))

    model.add(layers.Dense(num_classes, activation='softmax'))

    learning_rate = trial.suggest_float('learning_rate', 1e-4, 1e-2, log=True)
    optimizer = keras.optimizers.Adam(learning_rate=learning_rate)

    model.compile(optimizer=optimizer,
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])

    history = model.fit(X_train, y_train,
                        validation_split=0.2,
                        epochs=10,
                        batch_size=trial.suggest_categorical('batch_size', [32, 64, 128]),
                        verbose=0)

    val_accuracy = max(history.history['val_accuracy'])
    return val_accuracy

# %%
# Create Optuna study for optimization with persistent storage
study = optuna.create_study(
    direction='maximize',  # Assuming you are maximizing accuracy
    study_name="DNN_diseases_symptoms_dropextremelymore750withoutSMOTE_study", 
    storage=r"sqlite:///C:/Users/khiew/Downloads/dnn.db", 
    load_if_exists=True  # Load the study if it already exists, to resume from the last trial
)

# Optimize the study with your objective function, you can adjust the n_trials as needed
study.optimize(objective, n_trials=20)
# Print the best trial and hyperparameters
print("\nBest Trial:")
print(study.best_trial)
print("Best Hyperparameters:")
print(study.best_trial.params)
# Out:
# [I 2025-04-25 02:01:14,687] A new study created in RDB with name: DNN_diseases_symptoms_dropextremelymore750withoutSMOTE_study
# [I 2025-04-25 02:01:33,423] Trial 0 finished with value: 0.4813012480735779 and parameters: {'n_layers': 3, 'n_units_0': 64, 'activation_0': 'relu', 'dropout_rate_0': 0.3482627583235137, 'n_units_1': 64, 'activation_1': 'tanh', 'dropout_rate_1': 0.3847836579463273, 'n_units_2': 192, 'activation_2': 'relu', 'dropout_rate_2': 0.38161740012823964, 'learning_rate': 0.000987935430923719, 'batch_size': 64}. Best is trial 0 with value: 0.4813012480735779.
# [I 2025-04-25 02:02:01,292] Trial 1 finished with value: 0.4794969856739044 and parameters: {'n_layers': 2, 'n_units_0': 64, 'activation_0': 'tanh', 'dropout_rate_0': 0.4647676083755598, 'n_units_1': 128, 'activation_1': 'relu', 'dropout_rate_1': 0.4264926258898156, 'learning_rate': 0.006292331433229786, 'batch_size': 32}. Best is trial 0 with value: 0.4813012480735779.
# [I 2025-04-25 02:02:12,746] Trial 2 finished with value: 0.485347181558609 and parameters: {'n_layers': 3, 'n_units_0': 128, 'activation_0': 'tanh', 'dropout_rate_0': 0.46804532254550435, 'n_units_1': 192, 'activation_1': 'relu', 'dropout_rate_1': 0.42152970349153507, 'n_units_2': 64, 'activation_2': 'relu', 'dropout_rate_2': 0.22355486524801235, 'learning_rate': 0.00044468868127341436, 'batch_size': 128}. Best is trial 2 with value: 0.485347181558609.
# [I 2025-04-25 02:02:39,874] Trial 3 finished with value: 0.47517770528793335 and parameters: {'n_layers': 1, 'n_units_0': 256, 'activation_0': 'tanh', 'dropout_rate_0': 0.2057498577427782, 'learning_rate': 0.004174158476658126, 'batch_size': 32}. Best is trial 2 with value: 0.485347181558609.
# [I 2025-04-25 02:02:52,384] Trial 4 finished with value: 0.48775288462638855 and parameters: {'n_layers': 3, 'n_units_0': 256, 'activation_0': 'relu', 'dropout_rate_0': 0.4726164068331927, 'n_units_1': 192, 'activation_1': 'tanh', 'dropout_rate_1': 0.24993770220900627, 'n_units_2': 64, 'activation_2': 'tanh', 'dropout_rate_2': 0.354499636124194, 'learning_rate': 0.0005486769178899807, 'batch_size': 128}. Best is trial 4 with value: 0.48775288462638855.
# [I 2025-04-25 02:03:04,055] Trial 5 finished with value: 0.4704209864139557 and parameters: {'n_layers': 3, 'n_units_0': 64, 'activation_0': 'relu', 'dropout_rate_0': 0.49235171340840694, 'n_units_1': 192, 'activation_1': 'relu', 'dropout_rate_1': 0.22747925281435322, 'n_units_2': 192, 'activation_2': 'tanh', 'dropout_rate_2': 0.43124401498681414, 'learning_rate': 0.0067406186037412144, 'batch_size': 128}. Best is trial 4 with value: 0.48775288462638855.
# [I 2025-04-25 02:03:29,174] Trial 6 finished with value: 0.4915800988674164 and parameters: {'n_layers': 1, 'n_units_0': 64, 'activation_0': 'tanh', 'dropout_rate_0': 0.20574233762314836, 'learning_rate': 0.0003925634456548515, 'batch_size': 32}. Best is trial 6 with value: 0.4915800988674164.
# [I 2025-04-25 02:03:44,340] Trial 7 finished with value: 0.48649534583091736 and parameters: {'n_layers': 1, 'n_units_0': 256, 'activation_0': 'relu', 'dropout_rate_0': 0.3827437424389281, 'learning_rate': 0.0017554132866499997, 'batch_size': 64}. Best is trial 6 with value: 0.4915800988674164.
# [I 2025-04-25 02:03:53,084] Trial 8 finished with value: 0.4913614094257355 and parameters: {'n_layers': 1, 'n_units_0': 192, 'activation_0': 'relu', 'dropout_rate_0': 0.3354885594470997, 'learning_rate': 0.00033346862753091765, 'batch_size': 128}. Best is trial 6 with value: 0.4915800988674164.
# [I 2025-04-25 02:04:10,559] Trial 9 finished with value: 0.49300163984298706 and parameters: {'n_layers': 2, 'n_units_0': 192, 'activation_0': 'tanh', 'dropout_rate_0': 0.3268721430642717, 'n_units_1': 256, 'activation_1': 'tanh', 'dropout_rate_1': 0.29124151592962244, 'learning_rate': 0.00012069539228789684, 'batch_size': 64}. Best is trial 9 with value: 0.49300163984298706.
# [I 2025-04-25 02:04:28,275] Trial 10 finished with value: 0.4941498041152954 and parameters: {'n_layers': 2, 'n_units_0': 192, 'activation_0': 'tanh', 'dropout_rate_0': 0.28084135370413804, 'n_units_1': 256, 'activation_1': 'tanh', 'dropout_rate_1': 0.30501824859237986, 'learning_rate': 0.00011993106266929177, 'batch_size': 64}. Best is trial 10 with value: 0.4941498041152954.
# [I 2025-04-25 02:04:46,155] Trial 11 finished with value: 0.49256423115730286 and parameters: {'n_layers': 2, 'n_units_0': 192, 'activation_0': 'tanh', 'dropout_rate_0': 0.27600143902535107, 'n_units_1': 256, 'activation_1': 'tanh', 'dropout_rate_1': 0.3179397197727522, 'learning_rate': 0.00010753141439643658, 'batch_size': 64}. Best is trial 10 with value: 0.4941498041152954.
# [I 2025-04-25 02:05:04,089] Trial 12 finished with value: 0.49425914883613586 and parameters: {'n_layers': 2, 'n_units_0': 192, 'activation_0': 'tanh', 'dropout_rate_0': 0.28884482184157134, 'n_units_1': 256, 'activation_1': 'tanh', 'dropout_rate_1': 0.3077978140421515, 'learning_rate': 0.00011059658306756647, 'batch_size': 64}. Best is trial 12 with value: 0.49425914883613586.
# [I 2025-04-25 02:05:21,303] Trial 13 finished with value: 0.4926189184188843 and parameters: {'n_layers': 2, 'n_units_0': 128, 'activation_0': 'tanh', 'dropout_rate_0': 0.26585606487488717, 'n_units_1': 256, 'activation_1': 'tanh', 'dropout_rate_1': 0.3381148014921689, 'learning_rate': 0.0001887432591128211, 'batch_size': 64}. Best is trial 12 with value: 0.49425914883613586.
# [I 2025-04-25 02:05:39,151] Trial 14 finished with value: 0.49343904852867126 and parameters: {'n_layers': 2, 'n_units_0': 192, 'activation_0': 'tanh', 'dropout_rate_0': 0.2668103122408164, 'n_units_1': 256, 'activation_1': 'tanh', 'dropout_rate_1': 0.4992495087730253, 'learning_rate': 0.00019331039013585622, 'batch_size': 64}. Best is trial 12 with value: 0.49425914883613586.
# [I 2025-04-25 02:05:55,077] Trial 15 finished with value: 0.48797157406806946 and parameters: {'n_layers': 2, 'n_units_0': 128, 'activation_0': 'tanh', 'dropout_rate_0': 0.39446385894170066, 'n_units_1': 128, 'activation_1': 'tanh', 'dropout_rate_1': 0.27437626687322164, 'learning_rate': 0.000198881844489637, 'batch_size': 64}. Best is trial 12 with value: 0.49425914883613586.
# [I 2025-04-25 02:06:12,689] Trial 16 finished with value: 0.4794969856739044 and parameters: {'n_layers': 2, 'n_units_0': 192, 'activation_0': 'tanh', 'dropout_rate_0': 0.3009459314640777, 'n_units_1': 256, 'activation_1': 'tanh', 'dropout_rate_1': 0.20191166815279957, 'learning_rate': 0.0010555354882141861, 'batch_size': 64}. Best is trial 12 with value: 0.49425914883613586.
# [I 2025-04-25 02:06:26,747] Trial 17 finished with value: 0.48857298493385315 and parameters: {'n_layers': 1, 'n_units_0': 128, 'activation_0': 'tanh', 'dropout_rate_0': 0.23806560247774156, 'learning_rate': 0.00010184177584737184, 'batch_size': 64}. Best is trial 12 with value: 0.49425914883613586.
# [I 2025-04-25 02:06:45,013] Trial 18 finished with value: 0.49152541160583496 and parameters: {'n_layers': 2, 'n_units_0': 256, 'activation_0': 'tanh', 'dropout_rate_0': 0.3933131936217597, 'n_units_1': 192, 'activation_1': 'tanh', 'dropout_rate_1': 0.3618074794907218, 'learning_rate': 0.00024940440197066585, 'batch_size': 64}. Best is trial 12 with value: 0.49425914883613586.
# [I 2025-04-25 02:07:15,471] Trial 19 finished with value: 0.48316019773483276 and parameters: {'n_layers': 3, 'n_units_0': 192, 'activation_0': 'tanh', 'dropout_rate_0': 0.30146347666805856, 'n_units_1': 64, 'activation_1': 'relu', 'dropout_rate_1': 0.3067600138504169, 'n_units_2': 256, 'activation_2': 'tanh', 'dropout_rate_2': 0.2082872373137404, 'learning_rate': 0.0007168824714437996, 'batch_size': 32}. Best is trial 12 with value: 0.49425914883613586.
# Best Trial:
# FrozenTrial(number=12, state=TrialState.COMPLETE, values=[0.49425914883613586], datetime_start=datetime.datetime(2025, 4, 25, 2, 4, 46, 157908), datetime_complete=datetime.datetime(2025, 4, 25, 2, 5, 4, 82652), params={'n_layers': 2, 'n_units_0': 192, 'activation_0': 'tanh', 'dropout_rate_0': 0.28884482184157134, 'n_units_1': 256, 'activation_1': 'tanh', 'dropout_rate_1': 0.3077978140421515, 'learning_rate': 0.00011059658306756647, 'batch_size': 64}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'n_layers': IntDistribution(high=3, log=False, low=1, step=1), 'n_units_0': IntDistribution(high=256, log=False, low=64, step=64), 'activation_0': CategoricalDistribution(choices=('relu', 'tanh')), 'dropout_rate_0': FloatDistribution(high=0.5, log=False, low=0.2, step=None), 'n_units_1': IntDistribution(high=256, log=False, low=64, step=64), 'activation_1': CategoricalDistribution(choices=('relu', 'tanh')), 'dropout_rate_1': FloatDistribution(high=0.5, log=False, low=0.2, step=None), 'learning_rate': FloatDistribution(high=0.01, log=True, low=0.0001, step=None), 'batch_size': CategoricalDistribution(choices=(32, 64, 128))}, trial_id=147, value=None)
# Best Hyperparameters:
# {'n_layers': 2, 'n_units_0': 192, 'activation_0': 'tanh', 'dropout_rate_0': 0.28884482184157134, 'n_units_1': 256, 'activation_1': 'tanh', 'dropout_rate_1': 0.3077978140421515, 'learning_rate': 0.00011059658306756647, 'batch_size': 64}

# %%
# Load Optuna study
study = optuna.load_study(
    study_name="DNN_diseases_symptoms_dropextremelymore750withoutSMOTE_study",
    storage="sqlite:///C:/Users/khiew/Downloads/dnn.db"
)

# Get best parameters
best_params = study.best_trial.params

# Rebuild model using best parameters
best_model = keras.Sequential()
best_model.add(layers.Input(shape=(input_dim,)))

for i in range(best_params['n_layers']):
    best_model.add(layers.Dense(best_params[f'n_units_{i}'], activation=best_params[f'activation_{i}']))
    best_model.add(layers.Dropout(best_params[f'dropout_rate_{i}']))

best_model.add(layers.Dense(num_classes, activation='softmax'))

best_model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=best_params['learning_rate']),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# Fit the model and save training history
history = best_model.fit(
    X_train,
    y_train,
    epochs=20,
    batch_size=best_params['batch_size'],
    validation_split=0.2,
    verbose=1
)

# ===========================
# Plotting Training Lifecycle
# ===========================

plt.figure(figsize=(12, 5))

# Plot Accuracy
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy', marker='o')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy', marker='s')
plt.title('Model Accuracy over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

# Plot Loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss', marker='o')
plt.plot(history.history['val_loss'], label='Validation Loss', marker='s')
plt.title('Model Loss over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()
# Out:
# Epoch 1/20
# 1144/1144 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.1523 - loss: 4.1038 - val_accuracy: 0.4400 - val_loss: 2.3421
# Epoch 2/20
# 1144/1144 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.4100 - loss: 2.2124 - val_accuracy: 0.4815 - val_loss: 1.7750
# Epoch 3/20
# 1144/1144 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.4449 - loss: 1.8269 - val_accuracy: 0.4875 - val_loss: 1.6392
# Epoch 4/20
# 1144/1144 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.4545 - loss: 1.7229 - val_accuracy: 0.4904 - val_loss: 1.5880
# Epoch 5/20
# 1144/1144 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.4562 - loss: 1.6852 - val_accuracy: 0.4916 - val_loss: 1.5620
# Epoch 6/20
# 1144/1144 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.4622 - loss: 1.6416 - val_accuracy: 0.4909 - val_loss: 1.5481
# Epoch 7/20
# 1144/1144 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.4591 - loss: 1.6482 - val_accuracy: 0.4929 - val_loss: 1.5373
# Epoch 8/20
# 1144/1144 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.4590 - loss: 1.6377 - val_accuracy: 0.4919 - val_loss: 1.5316
# Epoch 9/20
# 1144/1144 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.4607 - loss: 1.6267 - val_accuracy: 0.4894 - val_loss: 1.5260
# Epoch 10/20
# 1144/1144 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.4640 - loss: 1.6205 - val_accuracy: 0.4914 - val_loss: 1.5226
# Epoch 11/20
# 1144/1144 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.4636 - loss: 1.6063 - val_accuracy: 0.4900 - val_loss: 1.5185
# Epoch 12/20
# 1144/1144 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.4578 - loss: 1.6249 - val_accuracy: 0.4905 - val_loss: 1.5181
# Epoch 13/20
# 1144/1144 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.4617 - loss: 1.6192 - val_accuracy: 0.4926 - val_loss: 1.5138
# Epoch 14/20
# 1144/1144 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.4659 - loss: 1.6077 - val_accuracy: 0.4929 - val_loss: 1.5140
# Epoch 15/20
# 1144/1144 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.4665 - loss: 1.6072 - val_accuracy: 0.4920 - val_loss: 1.5125
# Epoch 16/20
# 1144/1144 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.4703 - loss: 1.5930 - val_accuracy: 0.4900 - val_loss: 1.5104
# Epoch 17/20
# 1144/1144 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.4678 - loss: 1.5965 - val_accuracy: 0.4915 - val_loss: 1.5094
# Epoch 18/20
# 1144/1144 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.4693 - loss: 1.5869 - val_accuracy: 0.4923 - val_loss: 1.5096
# Epoch 19/20
# 1144/1144 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.4625 - loss: 1.5983 - val_accuracy: 0.4943 - val_loss: 1.5082
# Epoch 20/20
# 1144/1144 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.4660 - loss: 1.5971 - val_accuracy: 0.4909 - val_loss: 1.5071

# %%
from sklearn.metrics import classification_report

y_pred_test = np.argmax(best_model.predict(X_test), axis=1)
print("Classification Report on Test Set:")
print(classification_report(y_test, y_pred_test, target_names=label_encoder.classes_))
# Out:
# 715/715 ━━━━━━━━━━━━━━━━━━━━ 1s 673us/step
# Classification Report on Test Set:
#                                               precision    recall  f1-score   support
#
#                            actinic keratosis       0.00      0.00      0.00       192
#                          acute bronchiolitis       0.40      0.66      0.50       245
#                             acute bronchitis       0.68      0.42      0.52       275
#                           acute bronchospasm       0.74      0.46      0.57       174
#                          acute kidney injury       0.93      0.73      0.82       202
#                           acute pancreatitis       1.00      0.71      0.83       245
#                              acute sinusitis       0.32      0.24      0.28       188
#                        acute stress reaction       0.98      0.77      0.87       158
#                                      allergy       0.99      0.61      0.76       175
#                                       angina       0.60      0.55      0.58       178
#                                      anxiety       0.66      0.58      0.62       250
#                                 appendicitis       0.00      0.00      0.00       188
#                         arthritis of the hip       0.78      0.64      0.70       249
#                                       asthma       0.85      0.52      0.65       159
#           benign prostatic hyperplasia (bph)       0.12      1.00      0.21       261
#                                  blepharitis       0.00      0.00      0.00       152
#                            brachial neuritis       0.68      0.24      0.36       180
#                                     bursitis       0.32      0.47      0.38       249
#                       carpal tunnel syndrome       0.00      0.00      0.00       190
#                                cholecystitis       0.38      0.53      0.44       226
#                            chronic back pain       0.57      0.49      0.53       170
#                         chronic constipation       0.33      0.55      0.41       199
# chronic obstructive pulmonary disease (copd)       0.51      0.55      0.53       176
#                                  common cold       0.67      0.23      0.35       167
#               complex regional pain syndrome       1.00      0.15      0.26       251
#                                   concussion       0.78      0.80      0.79       254
#                               conjunctivitis       0.29      0.72      0.42       172
#                conjunctivitis due to allergy       0.43      0.91      0.58       231
#                           contact dermatitis       0.63      0.53      0.57       194
#                             cornea infection       0.89      0.68      0.77       183
#                                        croup       0.51      0.23      0.32       192
#                                     cystitis       0.52      0.46      0.49       224
#                    degenerative disc disease       0.22      0.16      0.19       172
#                                dental caries       0.63      0.81      0.71       245
#                                   depression       0.00      0.00      0.00       200
#                     developmental disability       0.38      0.76      0.50       188
#                                  diaper rash       0.87      0.70      0.77       175
#                               diverticulitis       0.55      0.48      0.51       259
#                                drug reaction       1.00      0.87      0.93       184
#                     dry eye of unknown cause       0.00      0.00      0.00       184
#                              ear drum damage       0.48      0.37      0.42       164
#                                       eczema       0.79      0.43      0.56       212
#                                  esophagitis       1.00      0.79      0.88       254
#   eustachian tube dysfunction (ear disorder)       0.88      0.68      0.77       184
#                          fracture of the rib       0.92      0.78      0.85       182
#                 fungal infection of the hair       1.00      0.42      0.59       242
#                                    gallstone       0.30      0.02      0.03       176
#                  gastrointestinal hemorrhage       0.62      0.66      0.64       242
#                                         gout       0.00      0.00      0.00       237
#                                  gum disease       0.61      0.62      0.62       182
#                                 heart attack       0.82      0.54      0.65       177
#                                heart failure       0.52      0.62      0.57       181
#                                  hemorrhoids       0.00      0.00      0.00       178
#                               herniated disk       0.34      0.29      0.31       171
#                                hiatal hernia       0.59      0.62      0.61       177
#                       hyperemesis gravidarum       1.00      0.55      0.71       163
#                   hypertensive heart disease       0.93      0.59      0.72       169
#                                 hypoglycemia       0.66      0.83      0.74       250
#            idiopathic excessive menstruation       0.28      0.66      0.39       174
#         idiopathic irregular menstrual cycle       0.00      0.00      0.00       181
#              idiopathic painful menstruation       0.00      0.00      0.00       163
#                   infectious gastroenteritis       0.42      0.45      0.44       258
#                            injury to the arm       0.30      0.73      0.43       251
#                            injury to the leg       0.72      0.47      0.57       238
#                          injury to the trunk       0.44      0.59      0.50       164
#                       ischemic heart disease       0.86      0.66      0.75       182
#                                 kidney stone       0.45      0.73      0.56       205
#                                liver disease       0.87      0.80      0.83       234
#                         macular degeneration       0.00      0.00      0.00       187
#                              marijuana abuse       0.60      0.56      0.58       245
#                           multiple sclerosis       0.94      0.70      0.80       198
#                                     neurosis       0.44      0.50      0.47       175
#                noninfectious gastroenteritis       0.41      0.31      0.35       221
#                                nose disorder       0.43      0.50      0.46       216
#                obstructive sleep apnea (osa)       0.67      0.76      0.71       268
#                               osteoarthritis       0.25      0.45      0.32       178
#               otitis externa (swimmer's ear)       0.42      0.37      0.39       202
#                                 otitis media       0.55      0.46      0.50       180
#                      pain after an operation       0.99      0.79      0.88       180
#                               panic disorder       0.66      0.59      0.62       189
#                  pelvic inflammatory disease       0.93      0.23      0.36       191
#                    peripheral nerve disorder       0.62      0.60      0.61       234
#                         personality disorder       0.00      0.00      0.00       154
#                                    pneumonia       0.86      0.50      0.63       238
#                     problem during pregnancy       0.78      0.70      0.74       173
#                                    psoriasis       0.25      0.36      0.30       192
#                           psychotic disorder       0.56      0.40      0.47       177
#                           pulmonary embolism       0.99      0.78      0.88       184
#                               pyelonephritis       0.49      0.29      0.36       190
#                      pyogenic skin infection       0.90      0.66      0.76       183
#                              rectal disorder       0.52      0.73      0.61       177
#                                schizophrenia       0.30      0.71      0.42       183
#               seasonal allergies (hay fever)       1.00      0.34      0.50       179
#                               sebaceous cyst       0.18      0.27      0.22       164
#                        seborrheic dermatitis       0.26      0.60      0.36       169
#                         seborrheic keratosis       0.00      0.00      0.00       190
#                                       sepsis       0.73      0.70      0.71       178
#                           sickle cell crisis       0.94      0.86      0.90       192
#                            sinus bradycardia       0.44      0.79      0.56       191
#                   skin pigmentation disorder       0.00      0.00      0.00       200
#                                   skin polyp       0.28      0.34      0.31       180
#                 smoking or tobacco addiction       0.75      0.68      0.71       175
#                              spinal stenosis       0.77      0.35      0.48       237
#                                  spondylosis       0.57      0.53      0.55       255
#                         spontaneous abortion       0.65      0.41      0.51       210
#                             sprain or strain       0.43      0.48      0.45       252
#                                 strep throat       0.99      0.73      0.84       253
#                                         stye       0.28      0.85      0.42       188
#           temporary or benign blood in urine       0.40      0.39      0.39       149
#                         threatened pregnancy       0.45      0.23      0.31       182
#                      urinary tract infection       0.49      0.51      0.50       166
#                                 vaginal cyst       0.22      0.75      0.34       270
#                                    vaginitis       0.00      0.00      0.00       195
#                                   vulvodynia       0.56      0.41      0.47       226
#
#                                     accuracy                           0.50     22863
#                                    macro avg       0.53      0.49      0.48     22863
#                                 weighted avg       0.54      0.50      0.49     22863
# c:\Users\khiew\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\khiew\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\khiew\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
